# %%
# !pip install oauth2
# !pip install django
# Out:
# Requirement already satisfied: oauth2 in c:\users\mildoosj\appdata\local\continuum\anaconda2\lib\site-packages
# Requirement already satisfied: httplib2 in c:\users\mildoosj\appdata\local\continuum\anaconda2\lib\site-packages (from oauth2)
# Collecting django
#   Downloading Django-1.11.2-py2.py3-none-any.whl (6.9MB)
# Requirement already satisfied: pytz in c:\users\mildoosj\appdata\local\continuum\anaconda2\lib\site-packages (from django)
# Installing collected packages: django
# Successfully installed django-1.11.2

# %%
# coding: utf-8

import oauth2 as oauth
import urllib2 as urllib
import json
from django.utils.encoding import smart_str
import matplotlib.pyplot as plt
import bokeh

def is_ascii(s):
    return all(ord(c) < 128 for c in s)

api_key = "YU0KmCt8JMhSml0EwurQDvUtv"
api_secret = "Iuu7zawVK2zmMJMeRgFGDl19LsqhkQs19MmKNUZSrCh7qk5oCq"
access_token_key = "825902122893971458-KMgjVVWqMibax6bDz8IwqOhzzQCQgnf"
access_token_secret = "wdfiGxkPBoRa6pWyhQE5FW2soUUAMeOCnuzKpVeSvIlGI"

_debug = 0

oauth_token    = oauth.Token(key=access_token_key, secret=access_token_secret)
oauth_consumer = oauth.Consumer(key=api_key, secret=api_secret)

signature_method_hmac_sha1 = oauth.SignatureMethod_HMAC_SHA1()

http_method = "GET"


http_handler  = urllib.HTTPHandler(debuglevel=_debug)
https_handler = urllib.HTTPSHandler(debuglevel=_debug)

def twitterreq(url, method, parameters):
    req = oauth.Request.from_consumer_and_token(oauth_consumer,
    token=oauth_token, http_method=http_method, http_url=url,
    parameters=parameters)

    req.sign_request(signature_method_hmac_sha1, oauth_consumer, oauth_token)

    headers = req.to_header()

    if http_method == "POST":
        encoded_post_data = req.to_postdata()
    else:
        encoded_post_data = None
        url = req.to_url()

    opener = urllib.OpenerDirector()
    opener.add_handler(http_handler)
    opener.add_handler(https_handler)

    response = opener.open(url, encoded_post_data)

    return response

def fetchsamples():
    url = "https://stream.twitter.com/1.1/statuses/sample.json"
    parameters = []
    response = twitterreq(url, "GET", parameters)
    for line in response:
        print line.strip()

def create_dictionary(sentiment):
    afinn_file  = sentiment
    scores = {}
    for line in afinn_file:
        term, score = line.split('\t')
        scores[term] = int(score)
    return scores

def create_west_coast_list(tweets):
    tweets_list = tweets
    list_of_tweets = []
    for line in tweets_list:
        tweet = json.loads(line)
        if tweet.has_key('user'):
            user = tweet["user"]
            if(user.has_key("location") and user["location"] is not None):
                location = user["location"]
                if(type(location) is not str):
                    location = smart_str(location)
                if(not is_ascii(location)):
                   continue
                #print(location)
                if(location.endswith(", CA") or location.endswith(", OR") or location.endswith(", WA") or location.endswith(", HI") or location.endswith(", AK")):
                    if tweet.has_key('text'):
                        text = tweet['text']
                        text = smart_str(text)
                        text = unicode( text, "utf-8" )
                        list_of_tweets.append(text)
    return list_of_tweets

def create_east_coast_list(tweets):
    tweets_list = tweets
    list_of_tweets = []
    for line in tweets_list:
        tweet = json.loads(line)
        if tweet.has_key('user'):
            user = tweet["user"]
            if(user.has_key("location") and user["location"] is not None):
                location = user["location"]
                if(type(location) is not str):
                    location = smart_str(location)
                if(not is_ascii(location)):
                   continue
                #print(location)
                if(location.endswith(", VA") or location.endswith(", DE") or location.endswith(", DC") or location.endswith(", PA") or location.endswith(", NJ") or location.endswith(", NY") or location.endswith(", ME") or location.endswith(", MA") or location.endswith(", NH") or location.endswith(", VT") or location.endswith(", CT")):
                    if tweet.has_key('text'):
                        text = tweet['text']
                        text = smart_str(text)
                        text = unicode( text, "utf-8" )
                        list_of_tweets.append(text)
    return list_of_tweets

def create_south_list(tweets):
    tweets_list = tweets
    list_of_tweets = []
    for line in tweets_list:
        tweet = json.loads(line)
        if tweet.has_key('user'):
            user = tweet["user"]
            if(user.has_key("location") and user["location"] is not None):
                location = user["location"]
                if(type(location) is not str):
                    location = smart_str(location)
                if(not is_ascii(location)):
                   continue
                #print(location)
                if(location.endswith(", TX") or location.endswith(", OK") or location.endswith(", LA") or location.endswith(", MS") or location.endswith(", AR") or location.endswith(", FL") or location.endswith(", AL") or location.endswith(", GA") or location.endswith(", SC") or location.endswith(", NC") or location.endswith(", MD") or location.endswith(", TN") or location.endswith(", WV")):
                    if tweet.has_key('text'):
                        text = tweet['text']
                        text = smart_str(text)
                        text = unicode( text, "utf-8" )
                        list_of_tweets.append(text)
    return list_of_tweets

def create_midwest_list(tweets):
    tweets_list = tweets
    list_of_tweets = []
    for line in tweets_list:
        tweet = json.loads(line)
        if tweet.has_key('user'):
            user = tweet["user"]
            if(user.has_key("location") and user["location"] is not None):
                location = user["location"]
                if(type(location) is not str):
                    location = smart_str(location)
                if(not is_ascii(location)):
                   continue
                #print(location)
                if(location.endswith(", ND") or location.endswith(", SD") or location.endswith(", NE") or location.endswith(", KS") or location.endswith(", MN") or location.endswith(", IO") or location.endswith(", MO") or location.endswith(", WI") or location.endswith(", MI") or location.endswith(", OH") or location.endswith(", IL") or location.endswith(", IN") or location.endswith(", KY")):
                    if tweet.has_key('text'):
                        text = tweet['text']
                        text = smart_str(text)
                        text = unicode( text, "utf-8" )
                        list_of_tweets.append(text)
    return list_of_tweets

def create_rocky_mountains_list(tweets):
    tweets_list = tweets
    list_of_tweets = []
    for line in tweets_list:
        tweet = json.loads(line)
        if tweet.has_key('user'):
            user = tweet["user"]
            if(user.has_key("location") and user["location"] is not None):
                location = user["location"]
                if(type(location) is not str):
                    location = smart_str(location)
                if(not is_ascii(location)):
                   continue
                #print(location)
                if(location.endswith(", MT") or location.endswith(", ID") or location.endswith(", WY") or location.endswith(", NE") or location.endswith(", UT") or location.endswith(", CO") or location.endswith(", AZ") or location.endswith(", NM")):
                    if tweet.has_key('text'):
                        text = tweet['text']
                        if(is_ascii(text)):
                            if(type(text) is not str):
                                continue
                            list_of_tweets.append(text)
    return list_of_tweets

def calculate_scores(tweets, dictionary):
    scores = []
    for i in tweets:
        score = 0
        words_list = i.split()
        for i in words_list:
            if i in dictionary:
                score = score + dictionary[i]
        scores.append(score)
    return scores

if __name__ == '__main__':

    list_tweets = []
    scores_west_coast = []
    scores_east_coast = []
    scores_south = []
    scores_midwest = []
    scores_rocky_mountains = []

#    fetchsamples()

    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    dictionary = create_dictionary(sent_file)

    west_coast_tweets = create_west_coast_list(tweet_file)
    
    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    dictionary = create_dictionary(sent_file)

    east_coast_tweets = create_east_coast_list(tweet_file)
    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    dictionary = create_dictionary(sent_file)

    south_tweets = create_south_list(tweet_file)
    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    dictionary = create_dictionary(sent_file)

    midwest_tweets = create_midwest_list(tweet_file)
    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    dictionary = create_dictionary(sent_file)

    rocky_mountains_tweets = create_rocky_mountains_list(tweet_file)

    scores_west_coast = calculate_scores(west_coast_tweets, dictionary)
    scores_east_coast = calculate_scores(east_coast_tweets, dictionary)
    scores_south = calculate_scores(south_tweets, dictionary)
    scores_midwest = calculate_scores(midwest_tweets, dictionary)
    scores_rocky_mountains = calculate_scores(rocky_mountains_tweets, dictionary)
    
    print(west_coast_tweets)
    """print(east_coast_tweets)
    print(south_tweets)
    print(midwest_tweets)
    print(rocky_mountains_tweets)
    print(scores_west_coast)
    print(scores_east_coast)
    print(scores_south)
    print(scores_midwest)
    print(scores_rocky_mountains)"""
# Out:
# [u'~  https://t.co/SOZqwdUJM3']
# []
# [u'RT @Drrake: This gotta be the funniest shit ever \U0001f62d\U0001f62d\U0001f62dLMFAO https://t.co/3Yf2zmXgmL']
# [u'&lt;  https://t.co/3bKUTPf82t']
# []
# [0]
# []
# [-4]
# [0]
# []

# %%
    print(midwest_tweets)
# Out:
# [u'&lt;  https://t.co/3bKUTPf82t']

# %%
from bokeh.plotting import figure, ColumnDataSource
from bokeh.io import show, output_notebook

# %%
scores_south = [2,3,5,-5,8,3-2]
sum_south = 0
for i in scores_south:
    sum_south = sum_south + i
avg_south = sum_south/len(scores_south)

scores_midwest = [-5, -2, -3, -3, 0, 3, 2, 1, 1, 0]
sum_midwest = 0
for i in scores_midwest:
    sum_midwest = sum_midwest + i
avg_midwest = sum_midwest/len(scores_midwest)

scores_west_coast = [2, 4, 0, 0, 1, -3, -4, 0, 0, -1]
sum_west_coast = 0
for i in scores_west_coast:
    sum_west_coast = sum_west_coast + i
avg_west_coast = sum_west_coast/len(scores_west_coast)

scores_east_coast = [4, 0, -1, 4, 3, 2, 0, 0, -3]
sum_east_coast = 0
for i in scores_east_coast:
    sum_east_coast = sum_east_coast + i
avg_east_coast = sum_east_coast/len(scores_east_coast)

scores_rocky_mountains = [1, 4, 0, 0, 0, -2, -3, 0, 0, 1, -1]
sum_rocky_mountains = 0
for i in scores_rocky_mountains:
    sum_rocky_mountains = sum_rocky_mountains + i
avg_rocky_mountains = sum_rocky_mountains/len(scores_rocky_mountains)

avg = [avg_south, avg_midwest, avg_west_coast, avg_east_coast, avg_rocky_mountains]

p = figure(x_axis_label = "scores_south", y_axis_label = "scores_south")
p.circle(scores_south, avg)
q = figure(x_axis_label = "scores_midwest", y_axis_label = "scores_midwest")
q.circle(scores_midwest, avg)
w = figure(x_axis_label = "scores_wc", y_axis_label = "scores_wc")
w.circle(scores_west_coast, avg)
e = figure(x_axis_label = "scores_ec", y_axis_label = "scores_ec")
e.circle(scores_east_coast, avg)
r = figure(x_axis_label = "scores_rm", y_axis_label = "scores_rm")
r.circle(scores_rocky_mountains, avg)
output_notebook()
show(p)
show(q)
show(w)
show(e)
show(r)
# Out:
# C:\Users\MildoOSJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# C:\Users\MildoOSJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# C:\Users\MildoOSJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# C:\Users\MildoOSJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# C:\Users\MildoOSJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="35333105-9401-4873-9108-e2a64f5301cc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a6c5195a-250a-4f18-bbd3-da3acefeb1a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a6c5195a-250a-4f18-bbd3-da3acefeb1a9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a6c5195a-250a-4f18-bbd3-da3acefeb1a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a6c5195a-250a-4f18-bbd3-da3acefeb1a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"17dde043-fb7c-478b-87c6-b50c282afa42":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1263240a-7d7c-4177-880a-778dc9c1e5bb","type":"PanTool"},{"id":"074ca02e-6d9f-46d6-97a1-88a80fcdb65e","type":"WheelZoomTool"},{"id":"6c366312-6577-4609-b562-1bebea9891ab","type":"BoxZoomTool"},{"id":"a10aa475-be9d-4d76-99b9-1507900c0b46","type":"SaveTool"},{"id":"5ffbb662-61e2-49da-be2e-3172416bed26","type":"ResetTool"},{"id":"8da85e24-b9d9-47d8-8e4b-20fdb377313d","type":"HelpTool"}]},"id":"cafd5e31-c246-4635-9b18-f727db01609b","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"2532f69c-4550-41ac-b26d-df927c6616b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"15c4aecc-2721-4262-8664-61edf8baa317","type":"BasicTicker"}},"id":"a15d21c8-98bc-4b83-943a-33046dd77362","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b549409-7f14-4980-8078-f40d99b7f778","type":"Circle"},{"attributes":{"below":[{"id":"73216bf0-6c83-427e-873d-5275596dba84","type":"LinearAxis"}],"left":[{"id":"dd2e6054-18b5-4335-8eda-e42f89fd7d84","type":"LinearAxis"}],"renderers":[{"id":"73216bf0-6c83-427e-873d-5275596dba84","type":"LinearAxis"},{"id":"72efd144-6324-40ca-ad95-561db91e8f58","type":"Grid"},{"id":"dd2e6054-18b5-4335-8eda-e42f89fd7d84","type":"LinearAxis"},{"id":"a15d21c8-98bc-4b83-943a-33046dd77362","type":"Grid"},{"id":"0a6a9a8d-2c6e-4dad-aea5-2c62ad5b92dc","type":"BoxAnnotation"},{"id":"2e180297-67bc-48a0-bc46-dc146484231f","type":"GlyphRenderer"}],"title":{"id":"9cbd1f71-372d-4fcb-a423-05fa9ae6e628","type":"Title"},"tool_events":{"id":"33ecb8c3-c43f-4c4e-9ee4-b950e7c3425e","type":"ToolEvents"},"toolbar":{"id":"cafd5e31-c246-4635-9b18-f727db01609b","type":"Toolbar"},"x_range":{"id":"867c53b2-f00a-47b4-ad84-9f71f47b544a","type":"DataRange1d"},"y_range":{"id":"277be559-d60f-46b2-a886-77cf57fc6e12","type":"DataRange1d"}},"id":"2532f69c-4550-41ac-b26d-df927c6616b8","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":
type":"WheelZoomTool"},{"attributes":{"plot":{"id":"8d219d92-ed44-41bd-838e-f43672be1a96","subtype":"Figure","type":"Plot"}},"id":"38384864-9c67-49db-9ef5-d72ac3bc94f0","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"10108b32-3b02-4279-bffc-e5fbecd2e14a","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,4,0,0,0,-2,-3,0,0,1,-1 ...

# %%
j = figure(x_axis_label = "scores", y_axis_label = "scores")
j.circle(avg, avg)
output_notebook()
show(j)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a297c59f-aa9a-4ffb-9a8f-088f08697086">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ea11b60-59ac-43e3-a7e5-42e1b0277f53"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4ea11b60-59ac-43e3-a7e5-42e1b0277f53");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ea11b60-59ac-43e3-a7e5-42e1b0277f53");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ea11b60-59ac-43e3-a7e5-42e1b0277f53' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"611adc8f-943f-463c-941b-3835f4ea44fd":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cf48e9a-cc51-487c-9b53-9b4193c4f388","type":"Circle"},{"attributes":{"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"}},"id":"c75ad9fc-6d38-43c7-8f26-af2439f0c6ea","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"532af722-43fd-4f32-bf8e-c235d043bf48","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"}},"id":"6e1de272-f489-4841-9828-91ecfeafeff9","type":"PanTool"},{"attributes":{"callback":null},"id":"700f5cda-62e2-40dc-b94b-af475393a5c2","type":"DataRange1d"},{"attributes":{"axis_label":"scores","formatter":{"id":"75df6710-b50f-497b-971c-f8fcde780c2c","type":"BasicTickFormatter"},"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"},"ticker":{"id":"17609a51-a4f3-4aac-8635-bb7d42dd38fc","type":"BasicTicker"}},"id":"da1c0914-c3ee-494f-8974-2b51f4f1e4cb","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"441c16d2-2de6-4e14-b79a-fb45f3a21b2d","type":"Title"},{"attributes":{},"id":"27ff248b-d148-48c1-9ab5-3be18bb1297c","type":"ToolEvents"},{"attributes":{"below":[{"id":"81003d50-4d14-4fba-82db-000b6e7524de","type":"LinearAxis"}],"left":[{"id":"da1c0914-c3ee-494f-8974-2b51f4f1e4cb","type":"LinearAxis"}],"renderers":[{"id":"81003d50-4d14-4fba-82db-000b6e7524de","type":"LinearAxis"},{"id":"b6b0afaa-3a37-43c2-b945-77cc1c8dd1cd","type":"Grid"},{"id":"da1c0914-c3ee-494f-8974-2b51f4f1e4cb","type":"LinearAxis"},{"id":"02f6c962-dc0c-4dba-b722-4a0ff257bd73","type":"Grid"},{"id":"532af722-43fd-4f32-bf8e-c235d043bf48","type":"BoxAnnotation"},{"id":"52d89ced-a758-4c94-b214-9968c70db2b9","type":"GlyphRenderer"}],"title":{"id":"441c16d2-2de6-4e14-b79a-fb45f3a21b2d","type":"Title"},"tool_events":{"id":"27ff248b-d148-48c1-9ab5-3be18bb1297c","type":"ToolEvents"},"toolbar":{"id":"793cd9cd-62b6-4d73-9331-b5a52279cdc0","type":"Toolbar"},"x_range":{"id":"700f5cda-62e2-40dc-b94b-af475393a5c2","type":"DataRange1d"},"y_range":{"id":"0d754426-26e3-4487-ad58-245c01a9a7c5","type":"DataRange1d"}},"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"},"ticker":{"id":"17609a51-a4f3-4aac-8635-bb7d42dd38fc","type":"BasicTicker"}},"id":"02f6c962-dc0c-4dba-b722-4a0ff257bd73","type":"Grid"},{"attributes":{},"id":"6fecc465-2e00-415c-b054-7db69c5c0fc1","type":"BasicTicker"},{"attributes":{},"id":"17609a51-a4f3-4aac-8635-bb7d42dd38fc","type":"BasicTicker"},{"attributes":{"callback":null},"id":"0d754426-26e3-4487-ad58-245c01a9a7c5","type":"DataRange1d"},{"attributes":{"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"},"ticker":{"id":"6fecc465-2e00-415c-b054-7db69c5c0fc1","type":"BasicTicker"}},"id":"b6b0afaa-3a37-43c2-b945-77cc1c8dd1cd","type":"Grid"},{"attributes":{"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"}},"id":"6d5e70f4-76be-410f-a649-70535b47f2cf","type":"SaveTool"},{"attributes":{},"id":"75df6710-b50f-497b-971c-f8fcde780c2c","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"532af722-43fd-4f32-bf8e-c235d043bf48","type":"BoxAnnotation"},"plot":{"id":"24608bbc-fc9a-4deb-a1ca-85e4e3cdd431","subtype":"Figure","type":"Plot"}},"id":"25e8e14c-9680-466a-9e9d-7347b6075ad6","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"58e1b4aa-7a21-4f59-ab45-6346e2e8c118","type":"ColumnDataSource"},"gly ...

# %%
scores_south = [2,3,5,-8,10,25-8]
scores_south = [20,30,50,-16,15,25-8]
sdf = pd.DataFrame({
        "scores": scores_south,
    })
sdf

sdf1 = pd.DataFrame({
        "scores1": scores_south
    })
sdf1
# Out:
#    scores1
# 0       20
# 1       30
# 2       50
# 3      -16
# 4       15
# 5       17

# %%
from bokeh.charts import BoxPlot, output_file, show
from bokeh.sampledata.autompg import autompg as df

# Use Bokeh chart to make plot
p = bokeh.charts.BoxPlot(sdf, values='scores', label='scores', xlabel='scores', ylabel='scores')

# Display it
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f90d9ad-deb2-4f32-9098-d57f62ef9978"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6f90d9ad-deb2-4f32-9098-d57f62ef9978");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f90d9ad-deb2-4f32-9098-d57f62ef9978");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f90d9ad-deb2-4f32-9098-d57f62ef9978' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a95af44e-1886-4681-aa45-cb771a55bba3":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0808e882-7d25-43ea-bad6-bfbb615f5dfb","type":"Rect"},{"attributes":{"plot":{"id":"ca4f1f17-cae7-4fb4-9ca0-2adb7cbf701a","subtype":"Chart","type":"Plot"}},"id":"058b4d4f-eb59-41ab-bad8-a9d863506850","type":"SaveTool"},{"attributes":{"data_source":{"id":"be814c7d-7c7a-4b23-b351-583193f133f1","type":"ColumnDataSource"},"glyph":{"id":"d12ef0c7-96d8-41f7-9479-6efb0c7a0029","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a093b77c-38cb-414e-a5f8-59bf48b2d819","type":"GlyphRenderer"},{"attributes":{"label":{"value":"15"},"renderers":[{"id":"9f719087-1583-43ef-b1fb-ed79711a751f","type":"GlyphRenderer"},{"id":"a093b77c-38cb-414e-a5f8-59bf48b2d819","type":"GlyphRenderer"},{"id":"4b027db8-b5fb-41e8-ad2e-cc63eaa52b0a","type":"GlyphRenderer"}]},"id":"dfabf924-602f-4cb1-954d-04b03aa92c97","type":"LegendItem"},{"attributes":{"data_source":{"id":"137c1f2c-ef2b-47cf-81d7-0a50bcc4eb08","type":"ColumnDataSource"},"glyph":{"id":"ac5d7135-ac43-44ca-a187-c45d931e8a44","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6fcbc5cd-f4fe-4e9a-be85-c26a13b1f59a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fd616819-6f47-47d0-806d-be7654d79cbb","type":"ColumnDataSource"},"glyph":{"id":"5cc2a5be-6246-4bf7-9452-029b7c7906c7","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"eeea649f-a246-42a0-a96e-1430ab5a2daf","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bc8d250c-5d67-4766-9faa-34ab55714cd3","type":"Rect"},{"attributes":{"items":[{"id":"ff7cffc7-be65-4605-92d5-f464cf5ffcd6","type":"LegendItem"},{"id":"607ab59a-9bde-4ecf-8d39-f9325531c3c6","type":"LegendItem"},{"id":"7d692b80-cf95-4631-8db6-f0e7f1e7cc37","type":"LegendItem"},{"id":"f81d8c2f-c2e6-4b19-bdb7-b40b3f622bfb","type":"LegendItem"},{"id":"dfabf924-602f-4cb1-954d-04b03aa92c97","type":"LegendItem"},{"id":"db7e429c-2509-4b0e-92e8-1f47b0985a62","type":"LegendItem"}],"location":"top_left","plot":{"id":"ca4f1f17-cae7-4fb4-9ca0-2adb7cbf701a","subtype":"Chart","type":"Plot"}},"id":"e99df304-427e-4a7f-a4d0-0447a9c08f52","type":"Legend"},{"attributes":{},"id":"ed828ba2-4bba-4db5-ab3b-933672cca77a","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"scores":-16}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"scores":-16}],"line_alpha":[1.0],"line_color":["black"],"scores":[-16],"width":[0.8],"x":["-16"],"y":[-16.0]}},"id":"cb08081d-e4fd-4739-b30a-fe320d5b016e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e7ea09f-eef0-490e-99a7-56affbb19a10","type":"Rect"},{"attributes":{},"id":"dd8c60ab-ee1b-42e7-82d5-d76aa250a503","type":"BasicTickFormatter"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"eda37efd-3e85-468b-baec-7328067180c6","type":"Segment"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"scores":-16}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"scores":-16}],"line_alpha":[1.0],"line_color":["black"],"scores":[-16],"width":[0.8],"x":["- ...

# %%
p = BoxPlot(sdf, values="scores", width=400, height=400, label='scores', xlabel='scores', ylabel='scores')
show(p)
sdf
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="60d02412-0285-48f4-abd0-e68766d338d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("60d02412-0285-48f4-abd0-e68766d338d2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("60d02412-0285-48f4-abd0-e68766d338d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '60d02412-0285-48f4-abd0-e68766d338d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1db05923-35da-4f9c-8bb2-3b13e19c40e0":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"scores":50}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"scores":50}],"line_alpha":[1.0],"line_color":["black"],"scores":[50],"width":[0.8],"x":["50"],"y":[50.0]}},"id":"c19e1789-5a51-46dc-904a-cbeb5d6ef9eb","type":"ColumnDataSource"},{"attributes":{"label":{"value":"20"},"renderers":[{"id":"64e61e25-616b-4568-929c-6f3fd8999728","type":"GlyphRenderer"},{"id":"e4603a8a-aeb2-46bc-8c75-2f6172acb59c","type":"GlyphRenderer"},{"id":"d80b9b19-bd42-43a0-97a6-41067797a11d","type":"GlyphRenderer"}]},"id":"b717ac77-372c-4262-b012-16f06bb54f50","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"scores":15}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"scores":15}],"line_alpha":[1.0],"line_color":["black"],"scores":[15],"width":[0.8],"x":["15"],"y":[15.0]}},"id":"10a5477b-3ced-4bf6-b240-8126ee4f5221","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"scores":17}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"scores":17}],"line_alpha":[1.0],"line_color":["black"],"scores":[17],"width":[0.8],"x":["17"],"y":[17.0]}},"id":"9831f2c9-d5ff-4161-b65d-a47dc525014a","type":"ColumnDataSource"},{"attributes":{"label":{"value":"17"},"renderers":[{"id":"9d78f49a-2a1a-4a64-b105-45c12745062f","type":"GlyphRenderer"},{"id":"9c74f08e-523b-4da7-8c80-a271c7f7e092","type":"GlyphRenderer"},{"id":"af5990e3-23f9-4ec9-80ca-c8edbd32e9d7","type":"GlyphRenderer"}]},"id":"fc78d829-5ad4-48e1-9144-9909aa096bb5","type":"LegendItem"},{"attributes":{"data_source":{"id":"266d2b13-633a-483b-b169-6398c30368c5","type":"ColumnDataSource"},"glyph":{"id":"bf04e1d1-5cad-43c5-90ab-d39522e092ad","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"af5990e3-23f9-4ec9-80ca-c8edbd32e9d7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"scores":15},{"scores":15},{"scores":15},{"scores":15}],"scores":[15,15,15,15],"x0s":["15:0.5","15:0.65","15:0.5","15:0.65"],"x1s":["15:0.5","15:0.35","15:0.5","15:0.35"],"y0s":[15.0,15.0,15.0,15.0],"y1s":[15,15.0,15.0,15.0]}},"id":"6ecc8d3a-7e38-454b-878d-fb80331af119","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"scores":17},{"scores":17},{"scores":17},{"scores":17}],"scores":[17,17,17,17],"x0s":["17:0.5","17:0.65","17:0.5","17:0.65"],"x1s":["17:0.5","17:0.35","17:0.5","17:0.35"],"y0s":[17.0,17.0,17.0,17.0],"y1s":[17,17.0,17.0,17.0]}},"id":"266d2b13-633a-483b-b169-6398c30368c5","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"7e571eeb-bad7-4371-baa3-fd7b721739fc","type":"BoxAnnotation"},"plot":{"id":"00fd55d9-d454-43e3-9e3e-1bbb68dad934","subtype":"Chart","type":"Plot"}},"id":"738a5e64-e3a9-4edb-90b1-46f4451b5b9d","type":"BoxZoomTool"},{"attributes":{"axis_label":"scores","formatter":{"id":"d7340457-7f23-48fe-904b-cd2bedb2644d","type":"BasicTickFormatter"},"plot":{"id":"00fd55d9-d454-43e3-9e3e-1bbb68dad934","subtype":"Chart","type":"Plot"},"ticker":{"id":"4c7b53a1-b915-4b12-b32f-f494f33fd092","type":"BasicTicker"}},"id":"dc10d82c-0707-4146-a487-2c1d3170f1fa","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cc737da-d7f1-449f-93fe-6853988552b1","type":"Rect"},{"attributes":{},"id":"d7340457-7f23-48fe-904b-cd2bedb2644d","type":"B ...
#    scores
# 0      20
# 1      30
# 2      50
# 3     -16
# 4      15
# 5      17
